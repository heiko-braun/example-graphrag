# %%
import networkx as nx
import matplotlib.pyplot as plt
from core.util import load_object
from pyvis.network import Network
import re
from core.graph import build_graph_from_summaries

# %%
summaries = load_object("summaries")
graph = build_graph_from_summaries(summaries)

#nx.draw(graph)
#plt.show()

nt = Network('800px', '800px', notebook=True)
nt.toggle_hide_edges_on_drag(True)
nt.barnes_hut()

nt.from_nx(graph)
nt.show('output/ex.html')
# Out:
# Load 'summaries' from file ...
# Summary index 0 of 9:
# Added entity Climate change
# Added entity Global agriculture
# Added entity Human activities
# Added entity Burning of fossil fuels
# Added entity Deforestation
# Added entity Crop yields
# Added entity Livestock productivity
# Added entity Food systems
# Added entity Temperature
# Added entity Precipitation
# Added edge Climate change Global agriculture
# Added edge Human activities Climate change
# Added edge Human activities Burning of fossil fuels
# Added edge Human activities Deforestation
# Added edge Climate change Crop yields
# Added edge Climate change Livestock productivity
# Added edge Climate change Food systems
# Added edge Climate change Temperature
# Added edge Climate change Precipitation
# Summary index 1 of 9:
# Added entity Climate Change
# Added entity Agriculture
# Added entity Temperature
# Added entity Precipitation Patterns
# Added entity Crops
# Added entity Growing Season
# Added entity Reduced Yields
# Added entity Rising Temperatures
# Added entity Development of Crops
# Added entity Maturity of Crops
# Added entity Harvests
# Added entity Quality of Produce
# Added entity Extreme Heat
# Added entity Critical Growth Stages
# Added entity Flowering Stage
# Added entity Grain Filling Stage
# Added entity Precipitation Changes
# Added entity Regions
# Added edge Climate Change Agriculture
# Added edge Climate Change Temperature
# Added edge Climate Change Precipitation Patterns
# Added edge Rising Temperatures Growing Season
# Added edge Growing Season Reduced Yields
# Added edge Rising Temperatures Development of Crops
# Added edge Development of Crops Maturity of Crops
# Added edge Maturity of Crops Development of Crops
# Added edge Development of Crops Harvests
# Added edge Extreme Heat Crops
# Added edge Critical Growth Stages Extreme Heat
# Added edge Precipitation Patterns Precipitation Changes
# Added edge Precipitation Changes Regions
# Summary index 2 of 9:
# Added entity flowering
# Added entity grain filling
# Added entity precipitation patterns
# Added entity regions
# Added entity intense and frequent droughts
# Added entity increased rainfall
# Added entity flooding
# Added entity water availability
# Added entity irrigation
# Added entity water stress
# Added entity crops
# Added entity yields
# Added entity excessive rainfall
# Added entity topsoil
# Added entity plant diseases
# Added entity farmers
# Added edge regions precipitation patterns
# Added edge regions intense and frequent droughts
# Added edge regions increased rainfall and flooding
# Added edge intense and frequent droughts water availability
# Added edge water availability irrigation
# Added edge water availability water stress
# Added edge water stress crops
# Added edge water stress yields
# Added edge excessive rainfall crops
# Added edge flooding topsoil
# Added edge flooding plant diseases
# Added edge precipitation patterns farmers
# Summary index 3 of 9:
# Added entity Farmers
# Added entity Crops
# Added entity Climate change
# Added entity Livestock production
# Added entity Higher temperatures
# Added entity Animals
# Added entity Heat stress
# Added entity Growth rates
# Added entity Milk production
# Added entity Reproductive performance
# Added entity Diseases
# Added entity Parasites
# Added entity Health
# Added entity Productivity
# Added entity Changing weather patterns
# Added entity Grazing lands
# Added entity Water resources
# Added entity Pastoralists
# Added entity Herds
# Added edge Climate change Livestock production
# Added edge Higher temperatures Heat stress
# Added edge Heat stress Growth rates
# Added edge Heat stress Milk production
# Added edge Heat stress Reproductive performance
# Added edge Heat stress Diseases
# Added edge Heat stress Parasites
# Added edge Diseases Health
# Added edge Diseases Productivity
# Added edge Parasites Health
# Added edge Parasites Productivity
# Added edge Changing weather patterns Grazing lands
# Added edge Changing weather patterns Water resources
# Added edge Grazing lands Pastoralists
# Added edge Water resources Pastoralists
# Added edge Climate change Farmers
# Summary index 4 of 9:
# Added entity Pastoralists
# Added entity Herds
# Added entity Climate change
# Added entity Agriculture
# Added entity Extreme weather events
# Added entity Hurricanes
# Added entity Cyclones
# Added entity Wildfires
# Added entity Agricultural infrastructure
# Added entity Farms
# Added entity Irrigation systems
# Added entity Storage facilities
# Added entity Supply chains
# Added entity Farmers
# Added entity Agricultural sector
# Added entity Food security
# Added edge Climate change Pastoralists
# Added edge Climate change Agriculture
# Added edge Climate change Extreme weather events
# Added edge Extreme weather events Agricultural infrastructure
# Added edge Agricultural infrastructure Supply chains
# Added edge Supply chains Farmers
# Added edge Farmers Agricultural sector
# Added edge Climate change Food security
# Summary index 5 of 9:
# Added entity Farmers
# Added entity Broader agricultural sector
# Added entity Climate change
# Added entity Food security
# Added entity Agricultural productivity
# Added entity Many regions
# Added entity Food prices
# Added entity Low-income populations
# Added entity Adequate nutrition
# Added entity Existing inequalities
# Added entity Social unrest
# Added entity Migration
# Added entity Suitability of regions for specific crops
# Added entity Agricultural practices
# Added entity Crop varieties
# Added entity New conditions
# Added entity New technologies
# Added entity Knowledge
# Added edge Climate change Food security
# Added edge Agricultural productivity Many regions
# Added edge Agricultural productivity Food prices
# Added edge Food prices Low-income populations
# Added edge Low-income populations Adequate nutrition
# Added edge Existing inequalities Social unrest
# Added edge Existing inequalities Migration
# Added edge Suitability of regions for specific crops Agricultural practices
# Added edge Suitability of regions for specific crops Crop varieties
# Added edge Farmers New conditions
# Added edge New conditions New technologies
# Added edge New conditions Knowledge
# Summary index 6 of 9:
# Added entity Climate Change
# Added entity Agriculture
# Added entity Farmers
# Added entity New Conditions
# Added entity New Technologies
# Added entity Knowledge
# Added entity Adaptation Strategies
# Added entity Climate-Resilient Crop Varieties
# Added entity Water Management
# Added entity Irrigation Practices
# Added entity Sustainable Soil Management Techniques
# Added entity Climate Risk Management
# Added entity Agricultural Planning
# Added entity Policies
# Added entity Farming Communities
# Added entity Climate-Related Shocks
# Added edge Climate Change Agriculture
# Added edge Farmers New Conditions
# Added edge Farmers New Technologies
# Added edge Farmers Knowledge
# Added edge Adaptation Strategies Climate Change
# Added edge Climate-Resilient Crop Varieties Adaptation Strategies
# Added edge Water Management Adaptation Strategies
# Added edge Irrigation Practices Adaptation Strategies
# Added edge Sustainable Soil Management Techniques Adaptation Strategies
# Added edge Climate Risk Management Agricultural Planning
# Added edge Climate Risk Management Policies
# Added edge Farming Communities Climate-Related Shocks
# Summary index 7 of 9:
# Added entity Climate Change
# Added entity Global Agriculture
# Added entity Crop Yields
# Added entity Livestock Productivity
# Added entity Food Security
# Added entity Adaptation Strategies
# Added entity Agricultural Systems
# Added entity Food Production
# Added entity Sustainability of Agriculture
# Added entity Warming World
# Added edge Climate Change Global Agriculture
# Added edge Climate Change Crop Yields
# Added edge Climate Change Livestock Productivity
# Added edge Climate Change Food Security
# Added edge Climate Change Adaptation Strategies
# Added edge Adaptation Strategies Agricultural Systems
# Added edge Proactive Measures Food Production
# Added edge Proactive Measures Sustainability of Agriculture
# Added edge Sustainability of Agriculture Warming World
# Summary index 8 of 9:
# Added entity Agriculture
# Added entity Warming world
# Added edge Agriculture Warming world
# Warning: When  cdn_resources is 'local' jupyter notebook has issues displaying graphics on chrome/safari. Use cdn_resources='in_line' or cdn_resources='remote' if you have issues viewing graphics in a notebook.
# output/ex.html
#         <iframe
#             width="800px"
#             height="800px"
#             src="output/ex.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
